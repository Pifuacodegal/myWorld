# %% [markdown]
# Cohort 3: ELEMENTS OF DATA SCIENCE AND MACHINE LEARNING
#
#
# EXAM: SEMISTER EXAM II (PRACTICAL EXAM)
#
# TIME ALLOWED : 3 HOURS MAXIMUM
#
#
# Instruction: ATTEMPT THREE QUESTIONS INCLUDING QUESTION ONE
#
# (a) The EXAM is to understand your application concepts in class to complete a real-life data science project
#
# (b) It is NOT the best answers to earn marks but scientific approach to the problems in front of you
#
# (c) YOU ARE ONLY ALLOWED TO CONSULT YOUR NOTES OR NOTEBOOKS ONLY.
#
# (d) ALL ANSWERS TO THE QUESTIONS SHOULD BE MADE IN THIS NOTEBOOK. NO OTHER NOTEBOOK WILL BE MARKED.
#
# (e) Send in your responses as a notebook (including the datasets used) as one zipped folder to alon.muhame@witu.org

# %%
# Import libraries as neccessary 
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')


# import any other library that may be of help in the course of the test (Zero Marks)

# %% [markdown]
# # Question 1: Data pre-processing and Exploration

# %% [markdown]
# This Question relates to the College data set, which has been shared with you 'College.csv' on email. It contains a number of variables for 777 diferent universities and colleges in the US. Use the dataset to answer the questions below:

# %% [markdown]
# (a) Use a pandas function to read the data into Python. Call the loaded data college. Make sure that you have the directory set to the correct location for the data.

# %% [markdown]
# Look at the data used in the notebook by creating and running a new cell with just the code `college' in it. You should notice that the frst column is just the name of each university in a column named something like `Unnamed: 0'. We don’t really want `pandas' to treat this as data. However, it may be handy to have these names for later. Try the following commands and similarly look at the resulting data frames:

# %%
college2 = pd.read_csv('College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0': 'College'},
axis=1)
college3 = college3.set_index('College')

# %% [markdown]
# This has used the frst column in the fle as an index for the data frame. This means that pandas has given each row a name corresponding to the appropriate university. Now you should see
# that the frst data column is Private. Note that the names of the colleges appear on the left of the table. We also introduced a new python object above: a dictionary, which is specifed by dictionary (key, value) pairs. Keep your modifed version of the data with the following:

# %%
college = college3

# %%
import pandas as pd

# %%
df = pd.read_csv(r'c:\Users\Student\Desktop\2023.DCSE.0095.SS\College.csv')
print(df)
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college =pd.read_csv(r'c:\Users\Student\Desktop\2023.DCSE.0095.SS\College.csv')
print(college)
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
college.tail()
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
#      Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# 772         26         3089         2029      6797        3900    500
# 773         47         2849         1107     11520        4960    600
# 774         61         2793          166      6900        4200    617
# 775         99         5217           83     19840        6510    630
# 776         63         2988         1726      4990        3560    500
#
#      Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# ...

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   777 non-null    object
#  1   Private      777 non-null    object
#  2   Apps         777 non-null    int64
#  3   Accept       777 non-null    int64
#  4   Enroll       777 non-null    int64
#  5   Top10perc    777 non-null    int64
#  6   Top25perc    777 non-null    int64
#  7   F.Undergrad  777 non-null    int64
#  8   P.Undergrad  777 non-null    int64
#  9   Outstate     777 non-null    int64
#  10  Room.Board   777 non-null    int64
#  11  Books        777 non-null    int64
#  12  Personal     777 non-null    int64
#  13  PhD          777 non-null    int64
#  14  Terminal     777 non-null    int64
#  15  S.F.Ratio    777 non-null    float64
#  16  perc.alumni  777 non-null    int64
#  17  Expend       777 non-null    int64
#  18  Grad.Rate    777 non-null    int64
# ...

# %%
college.value_counts()
# Out:
# Unnamed: 0                         Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# Abilene Christian University       Yes      1660  1232    721     23         52         2885         537          7440      3300        450    2200      70   78        18.1       12           7041    60           1
# Shippensburg University of Penn.   No       5818  3281    1116    14         53         5268         300          7844      3504        450    1700      80   83        18.8       13           6719    72           1
# Saint Mary's College               Yes      888   734     393     26         60         1433         27           12730     4514        500    1525      74   95        9.9        31           11165   98           1
# ...

# %% [markdown]
# (b). Write code to produce a numerical summary of the variables in the data set.

# %%
#numeric summary
numericSummary = college.describe()
print(numericSummary)
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# (c) Use the pd.plotting.scatter_matrix() function to produce a scatterplot matrix of the frst columns [Top10perc, Apps, Enroll]. Recall that you can reference a list C of columns of a data frame A using A[C].

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from pandas.plotting import scatter_matrix

# %%
columns_of_dataset = ['Top10perc', 'Apps', 'Enroll']
scatter_matrix_data = college[columns_of_dataset]

# Plot the scatterplot matrix
pd.plotting.scatter_matrix(scatter_matrix_data)
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# (d) Use the boxplot() method of college to produce side-by-side boxplots of Outstate versus Private

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
college.boxplot(column='Outstate', by='Private', figsize=(8, 6))
plt.title('A Boxplot Showing Outstate versus Private')
plt.xlabel('Private')
plt.ylabel('Outstate')
# Out:
# Text(0, 0.5, 'Outstate')

# %% [markdown]
# (e) Create a new qualitative variable, called Elite, by binning the Top10perc variable into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%. Run code below

# %%
college['Elite'] = pd.cut(college['Top10perc'],
[0,0.5,1],
labels=['No', 'Yes'])

# %%
college['Elite'] = college['Top10perc'] > 50

# %%
college['Elite'] = college['Elite'].astype('category')

# %%
print(college[['Top10perc', 'Elite']])
# Out:
#      Top10perc  Elite
# 0           23  False
# 1           16  False
# 2           22  False
# 3           60   True
# 4           16  False
# ..         ...    ...
# 772          4  False
# 773         24  False
# 774         34  False
# 775         95   True
# 776         28  False
#
# [777 rows x 2 columns]

# %% [markdown]
# (e) Use the value_counts() method of college['Elite'] to see how many elite universities there are. Finally, use the boxplot() method again to produce side-by-side boxplots of Outstate versus Elite.

# %%
college['Elite'].value_counts()
# Out:
# Elite
# False    699
# True      78
# Name: count, dtype: int64

# %%
college.boxplot(column='Outstate', by='Elite', figsize=(8, 6))
plt.title('A graph showing a Boxplot of Outstate vs. Elite')
plt.xlabel('Elite')
plt.ylabel('Outstate')
# Out:
# Text(0, 0.5, 'Outstate')

# %% [markdown]
# (f) Use the plot.hist() method of college to produce some histograms with difering numbers of bins for a few of the quantitative variables. The command plt.subplots(2, 2) may be useful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments you can divide the screen up in other combinations.

# %% [markdown]
# (g) Continue exploring the data, and provide a brief summary of what you discover.

# %%
# Supply the code for the Question 2 (5 marks)

# %% [markdown]
# # Question 3: Data Exploration and Relationship

# %% [markdown]
# This Questions involves the Boston housing data set.

# %% [markdown]
# (a) To begin, load in the Auto data set into your environment. Make sure that the missing values have been removed from the data.

# %% [markdown]
# (b) Which of the predictors are quantitative, and which are qualitative?

# %% [markdown]
# (c) What is the range of each quantitative predictor? You can answer this using the min() and max() methods

# %% [markdown]
# (d) What is the mean and standard deviation of each quantitative predictor

# %% [markdown]
# (e) Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

# %% [markdown]
# (f) Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your fndings.

# %% [markdown]
# (g) Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer

# %% [markdown]
# # Question 4: Visualization of Relationships

# %%
# Given the code that shows names of KFC & Cafe Javas burgers in Kamwokya

name_list = [
    'Lobster roll',
    'Chicken caesar',
    'Bang bang chicken',
    'Ham and cheese',
    'Tuna and cucumber',
    'Egg'
]

kfc_price_list = [9.99, 7.99, 7.49, 7, 6.29, 4.99]
cj_price_list = [7.5, 5, 4.4, 5, 3.75, 2.25]

# HINT:  As you should have observed that in the previous Question, the chat plotted percentages on the `y` axis versus time on the `x` axis.
# Now we want to plot the sandwich names on the `y` axis and the prices on the `x` axis. See here sample code: 

plt.plot(kfc_price_list, name_list)
plt.xlabel('Price in USD');

# Modify this code to change the line graph into dot using the markers argument 'o' (5 marks)

# %%
import matplotlib.pyplot as plt

# %%
# HINT:  As you should have observed that in the previous Question, the chat plotted percentages on the `y` axis versus time on the `x` axis.
# Now we want to plot the sandwich names on the `y` axis and the prices on the `x` axis. See here sample code: 

plt.plot(kfc_price_list, name_list, label="KFC")
plt.xlabel('Price in USD');
plt.ylabel('Sandwich names')
plt.title('A graph showing Sandwich names against price in USD')
plt.legend(fontsize='xx-large')

# %%
# Modify this code to change the line graph into dot using the markers argument 'o' (5 marks)

plt.plot(kfc_price_list, name_list, "o", label="KFC")
plt.xlabel('Price in USD');
plt.ylabel('Sandwich names')
plt.title('A graph showing Sandwich names against price in USD')
plt.legend(fontsize='xx-large')

# %%
# Now modify the same code again adding other the line chart for the CJ as dots 
# with markers on the same graph (5 marks)

# %%
plt.plot(cj_price_list, name_list, "o", label= "cj")
plt.xlabel('Price in USD');
plt.title('A graph showing a line chart for CJ as dots.')
plt.ylabel("Sandwich names")
plt.legend(fontsize='xx-large')

# %%
# Using the code below connect the dots for price points for KFC and CJ together using horizontal lines

plt.hlines(name_list, cj_price_list, kfc_price_list, color='gray')  # (5 marks)

# %%
plt.plot(kfc_price_list, name_list, " o" ,label="KFC")
plt.plot(cj_price_list, name_list, "o", label= "cj")
plt.hlines(name_list, cj_price_list, kfc_price_list, color='gray')
plt.title('A graph showing dots for KFC and CJ together using horizontal lines')
plt.legend(fontsize='xx-large')
plt.xlabel('Price in USD');
plt.ylabel("Sandwich names")
# Out:
# Text(0, 0.5, 'Sandwich names')

# %% [markdown]
# # Question 5: Distribution (Bonus Optional Question)

# %%
# Run this code to install empiricaldist module for use on this Question 5
try:
    import empiricaldist
except ImportError:
    # !pip install empiricaldist

# %%
# Applying th concepts of hypothesis testing and analysis (Use the dataset we have using in class)

# Do people tend to gain weight as they get older? Using the cohort 3 dataset with two variables of weight and age. 

# Plot a distribution of weight. (5 marks)

# Extract the variable `'AGE'` from the DataFrame you created and assign it to `age`(recode it as 'age'). (3 marks)

# Plot the PMF of `age` as a bar chart, using `Pmf` from `empiricaldist` (5 marks)

# %%
import pandas as pd

# %%
df = pd.read_excel(r"c:\Users\Student\Desktop\2023.DCSE.0095.SS\cohort_3_dataset.xlsx")
print(df)
# Out:
#     S/N  Age  Height  Weight  Admission cohort 3
# 0     1   20  177.80      74                   1
# 1     2   27  157.50      47                   1
# 2     3   21  210.82      54                   1
# 3     4   23  187.96      30                   1
# 4     5   19  175.25      59                   1
# 5     6   24  175.25      65                   1
# 6     7   21  157.48      69                   1
# 7     8   19  167.64      57                   1
# 8     9   19  154.94      55                   1
# 9    10   22  162.56      78                   1
# 10   11   25  175.25      60                   1
# 11   12   27  172.72      80                   1
# 12   13   21  187.96      58                   1
# 13   14   19  165.10      50                   1
# 14   15   21  175.25      50                   1
# 15   16   21  175.25      50                   1
# 16   17   20  160.02      49                   1
# 17   18   23  162.56      70                   1
# ...

# %%
# Plot a distribution of weight. (5 marks)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from numpy import random

# %%
plt.figure(figsize=(18,5))
plt.title('A graph showing the weight of cohort three students')
sns.distplot(random.normal(loc=58.375, scale=10.345, size=1000), hist=False, label='Weight')
plt.legend(fontsize='xx-large')
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_7736\2984862816.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=58.375, scale=10.345, size=1000), hist=False, label='Weight')
# C:\Users\Student\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
pip install empiricaldist
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\Student\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from empiricaldist import Pmf

# %%
Weight = df['Weight']

# %%
pmfWeight = Pmf.from_seq( Weight, normalize=False)
type(pmfWeight)
# Out:
# empiricaldist.empiricaldist.Pmf

# %%
pmfWeight.head()
# Out:
# Weight
# 30    1
# 45    1
# 47    1
# Name: count, dtype: int64

# %%
pmfWeight.tail()
# Out:
# Weight
# 74    1
# 78    1
# 80    1
# Name: count, dtype: int64

# %%
pmfWeight[70]
# Out:
# 2

# %%
pmfWeight_norm = Pmf.from_seq(Weight, normalize=True)
pmfWeight_norm.head()
# Out:
# Weight
# 30    0.03125
# 45    0.03125
# 47    0.03125
# Name: proportion, dtype: float64

# %%
pmfWeight_norm[70]
# Out:
# 0.0625

# %%
# pmf provides a bar method that plots the values and their probabilities as a bar chart.
pmfWeight_norm.bar(label='student Weight')
plt.xlabel('Weight in kgs')
plt.ylabel('PMF')
plt.title('A  bar graph showing distribution of weight among cohort 3 students')
plt.legend()
